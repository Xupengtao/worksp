# %%
import numpy as np
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

#import modules
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data

# 指定使用GPU编号
import os
os.environ['CUDA_VISIBLE_DEVICES']='0'

#import data
mnist = input_data.read_data_sets("MNIST_data/", one_hot=True)
# Out:
# WARNING:tensorflow:From <ipython-input-1-a433a96b0c5c>:16: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From /home/shuzhilian/anaconda3/envs/mask_rcnn/lib/python3.5/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:260: maybe_download (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please write your own downloading logic.
# WARNING:tensorflow:From /home/shuzhilian/anaconda3/envs/mask_rcnn/lib/python3.5/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:262: extract_images (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# WARNING:tensorflow:From /home/shuzhilian/anaconda3/envs/mask_rcnn/lib/python3.5/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:267: extract_labels (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /home/shuzhilian/anaconda3/envs/mask_rcnn/lib/python3.5/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:110: dense_to_one_hot (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.one_hot on tensors.
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /home/shuzhilian/anaconda3/envs/mask_rcnn/lib/python3.5/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:290: DataSet.__init__ (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.

# %% [markdown]
# ## 加载训练好的模型

# %%
# 加载模型
model_name = 'mycnn-' + str(1000)
saver = tf.train.import_meta_graph('./ckpt/' + model_name + '/' + model_name + '.meta')

# %% [markdown]
# ## 测试模型

# %%
IMG_SIZE = 28
IMG_CHANNEL = 1


with tf.Session() as sess:
    saver.restore(sess, tf.train.latest_checkpoint('./ckpt/' + model_name + '/'))
    graph = tf.get_default_graph()
    # 获取输入和输出变量
    X = graph.get_tensor_by_name("Placeholder:0")
    pred = graph.get_tensor_by_name("Sigmoid:0")

    test_x = mnist.test.images
    test_y = mnist.test.labels
    
    
    for image, label in zip(test_x, test_y):
        image = np.reshape(image, (1, IMG_SIZE, IMG_SIZE, IMG_CHANNEL))
        predict = np.argmax(sess.run(pred, feed_dict={X: image}))
        
        if predict != np.argmax(label):
            plt.imshow(image.reshape((IMG_SIZE, IMG_SIZE)), cmap='gray')
            plt.show()
            print('该数字真实值是%d'%(np.argmax(label)))
            print('识别到该数字是%d\n'%(predict))
# Out:
# INFO:tensorflow:Restoring parameters from ./ckpt/mycnn-1000/mycnn-1000
# 该数字真实值是2
# 识别到该数字是9
# 该数字真实值是4
# 识别到该数字是2
# 该数字真实值是6
# 识别到该数字是0
# 该数字真实值是8
# 识别到该数字是4
# 该数字真实值是2
# 识别到该数字是3
# 该数字真实值是9
# 识别到该数字是1
# 该数字真实值是5
# 识别到该数字是3
# 该数字真实值是6
# 识别到该数字是0
# 该数字真实值是3
# 识别到该数字是5
# 该数字真实值是8
# 识别到该数字是0
# 该数字真实值是8
# 识别到该数字是2
# 该数字真实值是8
# 识别到该数字是0
# 该数字真实值是7
# 识别到该数字是3
# 该数字真实值是0
# 识别到该数字是6
# 该数字真实值是4
# 识别到该数字是9
# 该数字真实值是7
# 识别到该数字是2
# 该数字真实值是8
# 识别到该数字是7
# 该数字真实值是7
# 识别到该数字是9
# 该数字真实值是2
# 识别到该数字是3
# 该数字真实值是3
# 识别到该数字是5
# 该数字真实值是8
# 识别到该数字是9
# 该数字真实值是1
# 识别到该数字是2
# 该数字真实值是6
# 识别到该数字是0
# 该数字真实值是6
# 识别到该数字是5
# 该数字真实值是7
# 识别到该数字是3
# 该数字真实值是8
# 识别到该数字是4
# 该数字真实值是3
# 识别到该数字是8
# 该数字真实值是7
# 识别到该数字是8
# 该数字真实值是7
# 识别到该数字是9
# 该数字真实值是6
# 识别到该数字是8
# 该数字真实值是9
# 识别到该数字是4
# 该数字真实值是7
# 识别到该数字是2
# 该数字真实值是9
# 识别到该数字是4
# 该数字真实值是9
# 识别到该数字是5
# 该数字真实值是7
# 识别到该数字是1
# 该数字真实值是7
# 识别到该数字是2
# 该数字真实值是8
# 识别到该数字是3
# 该数字真实值是7
# 识别到该数字是2
# 该数字真实值是8
# 识别到该数字是2
# 该数字真实值是5
# 识别到该数字是3
# 该数字真实值是8
# 识别到该数字是4
# 该数字真实值是7
# 识别到该数字是1
# 该数字真实值是7
# 识别到该数字是9
# 该数字真实值是1
# 识别到该数字是5
# 该数字真实值是8
# 识别到该数字是7
# 该数字真实值是4
# 识别到该数字是6
# 该数字真实值是0
# 识别到该数字是6
# 该数字真实值是7
# 识别到该数字是9
# 该数字真实值是0
# 识别到该数字是6
# 该数字真实值是6
# 识别到该数字是5
# 该数字真实值是3
# 识别到该数字是7
# 该数字真实值是9
# 识别到该数字是5
# 该数字真实值是7
# 识别到该数字是9
# 该数字真实值是7
# 识别到该数字是2
# 该数字真实值是8
# 识别到该数字是5
# 该数字真实值是2
# 识别到该数字是8
# 该数字真实值是6
# 识别到该数字是4
# 该数字真实值是8
# 识别到该数字是5
# 该数字真实值是8
# 识别到该数字是3
# 该数字真实值是9
# 识别到该数字是4
# 该数字真实值是7
# 识别到该数字是2
# 该数字真实值是8
# 识别到该数字是2
# 该数字真实值是7
# 识别到该数字是2
# 该数字真实值是7
# 识别到该数字是9
# 该数字真实值是4
# 识别到该数字是9
# 该数字真实值是7
# 识别到该数字是9
# 该数字真实值是3
# 识别到该数字是7
# 该数字真实值是6
# 识别到该数字是0
# 该数字真实值是4
# 识别到该数字是9
# 该数字真实值是4
# 识别到该数字是9
# 该数字真实值是1
# 识别到该数字是2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-be2c91a64688> in <module>()
#      20         if predict != np.argmax(label):
#      21             plt.imshow(image.reshape((IMG_SIZE, IMG_SIZE)), cmap='gray')
# ---> 22             plt.show()
#      23             print('该数字真实值是%d'%(np.argmax(label)))
#      24             print('识别到该数字是%d\n'%(predict))
#
# ~/anaconda3/envs/mask_rcnn/lib/python3.5/site-packages/matplotlib/pyplot.py in show(*args, **kw)
#     251     """
#     252     global _show
# --> 253     return _show(*args, **kw)
#     254
#     255
#
# ~/anaconda3/envs/mask_rcnn/lib/python3.5/site-packages/ipykernel/pylab/backend_inline.py in show(close, block)
#      34     try:
#      35         for figure_manager in Gcf.get_all_fig_managers():
# ---> 36             display(figure_manager.canvas.figure)
#      37     finally:
#      38         show._to_draw = []
#
# ~/anaconda3/envs/mask_rcnn/lib/python3.5/site-packages/IPython/core/display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     296             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     297         else:
# --> 298             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     299             if not format_dict:
#     300                 # nothing to display (e.g. _ipython_display_ took over)
#
# ~/anaconda3/envs/mask_rcnn/lib/python3.5/site-packages/IPython/core/formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# <decorator-gen-9> in __call__(self, obj)
#
# ~/anaconda3/envs/mask_rcnn/lib/python3.5/site-packages/IPython/core/formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# ~/anaconda3/envs/mask_rcnn/lib/python3.5/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~/anaconda3/envs/mask_rcnn/lib/python3.5/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     239
#     240     if 'png' in formats:
# --> 241         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     242     if 'retina' in formats or 'png2x' in formats:
#     243         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ~/anaconda3/envs/mask_rcnn/lib/python3.5/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     123
#     124     bytes_io = BytesIO()
# --> 125     fig.canvas.print_figure(bytes_io, **kw)
#     126     data = bytes_io.getvalue()
#     127     if fmt == 'svg':
#
# ~/anaconda3/envs/mask_rcnn/lib/python3.5/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2212                     **kwargs)
#    2213                 renderer = self.figure._cachedRenderer
# -> 2214                 bbox_inches = self.figure.get_tightbbox(renderer)
#    2215
#    2216                 bbox_artists = kwargs.pop("bbox_extra_artists", None)
#
# ~/anaconda3/envs/mask_rcnn/lib/python3.5/site-packages/matplotlib/figure.py in get_tightbbox(self, renderer)
#    2188         for ax in self.axes:
#    2189             if ax.get_visible():
# -> 2190                 bb.append(ax.get_tightbbox(renderer))
#    2191
#    2192         if len(bb) == 0:
#
# ~/anaconda3/envs/mask_rcnn/lib/python3.5/site-packages/matplotlib/axes/_base.py in get_tightbbox(self, renderer, call_axes_locator)
#    4168             bb.append(self._right_title.get_window_extent(renderer))
#    4169
# -> 4170         bb_xaxis = self.xaxis.get_tightbbox(renderer)
#    4171         if bb_xaxis:
#    4172             bb.append(bb_xaxis)
#
# ~/anaconda3/envs/mask_rcnn/lib/python3.5/site-packages/matplotlib/axis.py in get_tightbbox(self, renderer)
#    1165         bb = [b for b in bb if b.width != 0 or b.height != 0]
#    1166         if bb:
# -> 1167             _bbox = mtransforms.Bbox.union(bb)
#    1168             return _bbox
#    1169         else:
#
# ~/anaconda3/envs/mask_rcnn/lib/python3.5/site-packages/matplotlib/transforms.py in union(bboxes)
#     747         x0 = np.min([bbox.xmin for bbox in bboxes])
#     748         x1 = np.max([bbox.xmax for bbox in bboxes])
# --> 749         y0 = np.min([bbox.ymin for bbox in bboxes])
#     750         y1 = np.max([bbox.ymax for bbox in bboxes])
#     751         return Bbox([[x0, y0], [x1, y1]])
#
# KeyboardInterrupt:
